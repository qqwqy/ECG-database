# %%
# !pip install wfdb

# !wget -r -N -c -np https://physionet.org/files/mitdb/1.0.0/
# 利用wget完成数据下载
# Out:
# Requirement already satisfied: wfdb in /usr/local/lib/python3.10/dist-packages (4.1.2)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.25.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.0.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.31.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2024.2.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# --2024-05-07 04:33:50--  https://physionet.org/files/mitdb/1.0.0/
# Resolving physionet.org (physionet.org)... 18.13.52.205
# Connecting to physionet.org (physionet.org)|18.13.52.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]  22.86K  --.-KB/s    in 0.02s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-05-07 04:33:51 (1007 KB/s) - ‘physionet.org/files/mitdb/1.0.0/index.html’ saved [23410]
#
# Loading robots.txt; please ignore errors.
# --2024-05-07 04:33:51--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2024-05-07 04:33:51--  https://physionet.org/files/mitdb/1.0.0/mitdbdir/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘physionet.org/files/mitdb/1.0.0/mitdbdir/index.html’ not modified on server. Omitting download.
#
# --2024-05-07 04:33:51--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/index.html’
#
# physionet.org/files     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-05-07 04:33:51 (1.30 GB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/index.html’ saved [8320]
#
# --2024-05-07 04:33:51--  https://physionet.org/files/mitdb/1.0.0/100.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘physionet.org/files/mitdb/1.0.0/100.atr’ not modified on server. Omitting download.
#
# --2024-05-07 04:33:51--  https://physionet.org/files/mitdb/1.0.0/100.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘physionet.org/files/mitdb/1.0.0/100.dat’ not modified on server. Omitting download.
#
# --2024-05-07 04:33:51--  https://physionet.org/files/mitdb/1.0.0/100.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘physionet.org/files/mitdb/1.0.0/100.hea’ not modified on server. Omitting download.
#
# --2024-05-07 04:33:52--  https://physionet.org/files/mitdb/1.0.0/100.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘physionet.org/files/mitdb/1.0.0/100.xws’ not modified on server. Omitting download.
#
# --2024-05-07 04:33:52--  https://physionet.org/files/mitdb/1.0.0/101.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘physionet.org/files/mitdb/1.0.0/101.atr’ not modified on server. Omitting download.
#
# --2024-05-07 04:33:52--  https://physionet.org/files/mitdb/1.0.0/101.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 1950000 (1.9M), 606873 (593K) remaining [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/101.dat’
#
# physionet.org/files 100%[+++++++++++++======>]   1.86M   290KB/s    in 2.0s
#
# 2024-05-07 04:33:54 (290 KB/s) - ‘physionet.org/files/mitdb/1.0.0/101.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:33:54--  https://physionet.org/files/mitdb/1.0.0/101.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 131 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/101.hea’
#
# physionet.org/files 100%[===================>]     131  --.-KB/s    in 0s
#
# 2024-05-07 04:33:54 (47.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/101.hea’ saved [131/131]
#
# --2024-05-07 04:33:54--  https://physionet.org/files/mitdb/1.0.0/101.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/101.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:33:54 (27.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/101.xws’ saved [88/88]
#
# --2024-05-07 04:33:54--  https://physionet.org/files/mitdb/1.0.0/102-0.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4424 (4.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/102-0.atr’
#
# physionet.org/files 100%[===================>]   4.32K  --.-KB/s    in 0s
#
# 2024-05-07 04:33:54 (1.03 GB/s) - ‘physionet.org/files/mitdb/1.0.0/102-0.atr’ saved [4424/4424]
#
# --2024-05-07 04:33:54--  https://physionet.org/files/mitdb/1.0.0/102.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4424 (4.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/102.atr’
#
# physionet.org/files 100%[===================>]   4.32K  --.-KB/s    in 0s
#
# 2024-05-07 04:33:55 (943 MB/s) - ‘physionet.org/files/mitdb/1.0.0/102.atr’ saved [4424/4424]
#
# --2024-05-07 04:33:55--  https://physionet.org/files/mitdb/1.0.0/102.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/102.dat’
#
# physionet.org/files 100%[===================>]   1.86M   294KB/s    in 6.6s
#
# 2024-05-07 04:34:01 (289 KB/s) - ‘physionet.org/files/mitdb/1.0.0/102.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:01--  https://physionet.org/files/mitdb/1.0.0/102.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 204 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/102.hea’
#
# physionet.org/files 100%[===================>]     204  --.-KB/s    in 0s
#
# 2024-05-07 04:34:02 (169 MB/s) - ‘physionet.org/files/mitdb/1.0.0/102.hea’ saved [204/204]
#
# --2024-05-07 04:34:02--  https://physionet.org/files/mitdb/1.0.0/102.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/102.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:02 (49.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/102.xws’ saved [88/88]
#
# --2024-05-07 04:34:02--  https://physionet.org/files/mitdb/1.0.0/103.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4196 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/103.atr’
#
# physionet.org/files 100%[===================>]   4.10K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:02 (1.23 GB/s) - ‘physionet.org/files/mitdb/1.0.0/103.atr’ saved [4196/4196]
#
# --2024-05-07 04:34:02--  https://physionet.org/files/mitdb/1.0.0/103.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/103.dat’
#
# physionet.org/files 100%[===================>]   1.86M   284KB/s    in 6.5s
#
# 2024-05-07 04:34:09 (293 KB/s) - ‘physionet.org/files/mitdb/1.0.0/103.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:09--  https://physionet.org/files/mitdb/1.0.0/103.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/103.hea’
#
# physionet.org/files 100%[===================>]     142  --.-KB/s    in 0s
#
# 2024-05-07 04:34:09 (134 MB/s) - ‘physionet.org/files/mitdb/1.0.0/103.hea’ saved [142/142]
#
# --2024-05-07 04:34:09--  https://physionet.org/files/mitdb/1.0.0/103.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/103.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:10 (86.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/103.xws’ saved [88/88]
#
# --2024-05-07 04:34:10--  https://physionet.org/files/mitdb/1.0.0/104.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4948 (4.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/104.atr’
#
# physionet.org/files 100%[===================>]   4.83K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:10 (589 MB/s) - ‘physionet.org/files/mitdb/1.0.0/104.atr’ saved [4948/4948]
#
# --2024-05-07 04:34:10--  https://physionet.org/files/mitdb/1.0.0/104.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/104.dat’
#
# physionet.org/files 100%[===================>]   1.86M   279KB/s    in 6.8s
#
# 2024-05-07 04:34:17 (281 KB/s) - ‘physionet.org/files/mitdb/1.0.0/104.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:17--  https://physionet.org/files/mitdb/1.0.0/104.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 378 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/104.hea’
#
# physionet.org/files 100%[===================>]     378  --.-KB/s    in 0s
#
# 2024-05-07 04:34:17 (201 MB/s) - ‘physionet.org/files/mitdb/1.0.0/104.hea’ saved [378/378]
#
# --2024-05-07 04:34:17--  https://physionet.org/files/mitdb/1.0.0/104.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/104.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:18 (34.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/104.xws’ saved [88/88]
#
# --2024-05-07 04:34:18--  https://physionet.org/files/mitdb/1.0.0/105.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5638 (5.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/105.atr’
#
# physionet.org/files 100%[===================>]   5.51K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:18 (1.52 GB/s) - ‘physionet.org/files/mitdb/1.0.0/105.atr’ saved [5638/5638]
#
# --2024-05-07 04:34:18--  https://physionet.org/files/mitdb/1.0.0/105.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/105.dat’
#
# physionet.org/files 100%[===================>]   1.86M   295KB/s    in 6.5s
#
# 2024-05-07 04:34:25 (294 KB/s) - ‘physionet.org/files/mitdb/1.0.0/105.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:25--  https://physionet.org/files/mitdb/1.0.0/105.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 258 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/105.hea’
#
# physionet.org/files 100%[===================>]     258  --.-KB/s    in 0s
#
# 2024-05-07 04:34:25 (161 MB/s) - ‘physionet.org/files/mitdb/1.0.0/105.hea’ saved [258/258]
#
# --2024-05-07 04:34:25--  https://physionet.org/files/mitdb/1.0.0/105.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/105.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:25 (49.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/105.xws’ saved [88/88]
#
# --2024-05-07 04:34:25--  https://physionet.org/files/mitdb/1.0.0/106.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5476 (5.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/106.atr’
#
# physionet.org/files 100%[===================>]   5.35K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:26 (1.83 GB/s) - ‘physionet.org/files/mitdb/1.0.0/106.atr’ saved [5476/5476]
#
# --2024-05-07 04:34:26--  https://physionet.org/files/mitdb/1.0.0/106.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/106.dat’
#
# physionet.org/files 100%[===================>]   1.86M   291KB/s    in 6.7s
#
# 2024-05-07 04:34:33 (286 KB/s) - ‘physionet.org/files/mitdb/1.0.0/106.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:33--  https://physionet.org/files/mitdb/1.0.0/106.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/106.hea’
#
# physionet.org/files 100%[===================>]     158  --.-KB/s    in 0s
#
# 2024-05-07 04:34:33 (125 MB/s) - ‘physionet.org/files/mitdb/1.0.0/106.hea’ saved [158/158]
#
# --2024-05-07 04:34:33--  https://physionet.org/files/mitdb/1.0.0/106.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/106.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:33 (23.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/106.xws’ saved [88/88]
#
# --2024-05-07 04:34:33--  https://physionet.org/files/mitdb/1.0.0/107.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4406 (4.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/107.atr’
#
# physionet.org/files 100%[===================>]   4.30K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:33 (1.18 GB/s) - ‘physionet.org/files/mitdb/1.0.0/107.atr’ saved [4406/4406]
#
# --2024-05-07 04:34:33--  https://physionet.org/files/mitdb/1.0.0/107.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/107.dat’
#
# physionet.org/files 100%[===================>]   1.86M   298KB/s    in 6.5s
#
# 2024-05-07 04:34:40 (294 KB/s) - ‘physionet.org/files/mitdb/1.0.0/107.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:40--  https://physionet.org/files/mitdb/1.0.0/107.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 193 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/107.hea’
#
# physionet.org/files 100%[===================>]     193  --.-KB/s    in 0s
#
# 2024-05-07 04:34:40 (98.4 MB/s) - ‘physionet.org/files/mitdb/1.0.0/107.hea’ saved [193/193]
#
# --2024-05-07 04:34:40--  https://physionet.org/files/mitdb/1.0.0/107.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/107.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:40 (95.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/107.xws’ saved [88/88]
#
# --2024-05-07 04:34:40--  https://physionet.org/files/mitdb/1.0.0/108.at_
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3744 (3.7K) [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/108.at_’
#
# physionet.org/files 100%[===================>]   3.66K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:41 (2.23 GB/s) - ‘physionet.org/files/mitdb/1.0.0/108.at_’ saved [3744/3744]
#
# --2024-05-07 04:34:41--  https://physionet.org/files/mitdb/1.0.0/108.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3742 (3.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/108.atr’
#
# physionet.org/files 100%[===================>]   3.65K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:41 (1.21 GB/s) - ‘physionet.org/files/mitdb/1.0.0/108.atr’ saved [3742/3742]
#
# --2024-05-07 04:34:41--  https://physionet.org/files/mitdb/1.0.0/108.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/108.dat’
#
# physionet.org/files 100%[===================>]   1.86M   281KB/s    in 6.7s
#
# 2024-05-07 04:34:48 (283 KB/s) - ‘physionet.org/files/mitdb/1.0.0/108.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:48--  https://physionet.org/files/mitdb/1.0.0/108.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 311 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/108.hea’
#
# physionet.org/files 100%[===================>]     311  --.-KB/s    in 0s
#
# 2024-05-07 04:34:48 (173 MB/s) - ‘physionet.org/files/mitdb/1.0.0/108.hea’ saved [311/311]
#
# --2024-05-07 04:34:48--  https://physionet.org/files/mitdb/1.0.0/108.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/108.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:48 (49.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/108.xws’ saved [88/88]
#
# --2024-05-07 04:34:48--  https://physionet.org/files/mitdb/1.0.0/109.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5080 (5.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/109.atr’
#
# physionet.org/files 100%[===================>]   4.96K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:48 (2.49 GB/s) - ‘physionet.org/files/mitdb/1.0.0/109.atr’ saved [5080/5080]
#
# --2024-05-07 04:34:48--  https://physionet.org/files/mitdb/1.0.0/109.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/109.dat’
#
# physionet.org/files 100%[===================>]   1.86M   292KB/s    in 6.5s
#
# 2024-05-07 04:34:55 (294 KB/s) - ‘physionet.org/files/mitdb/1.0.0/109.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:34:55--  https://physionet.org/files/mitdb/1.0.0/109.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 195 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/109.hea’
#
# physionet.org/files 100%[===================>]     195  --.-KB/s    in 0s
#
# 2024-05-07 04:34:55 (17.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/109.hea’ saved [195/195]
#
# --2024-05-07 04:34:55--  https://physionet.org/files/mitdb/1.0.0/109.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/109.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:34:56 (5.72 MB/s) - ‘physionet.org/files/mitdb/1.0.0/109.xws’ saved [88/88]
#
# --2024-05-07 04:34:56--  https://physionet.org/files/mitdb/1.0.0/111.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4284 (4.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/111.atr’
#
# physionet.org/files 100%[===================>]   4.18K  --.-KB/s    in 0s
#
# 2024-05-07 04:34:56 (1.07 GB/s) - ‘physionet.org/files/mitdb/1.0.0/111.atr’ saved [4284/4284]
#
# --2024-05-07 04:34:56--  https://physionet.org/files/mitdb/1.0.0/111.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/111.dat’
#
# physionet.org/files 100%[===================>]   1.86M   286KB/s    in 6.8s
#
# 2024-05-07 04:35:03 (280 KB/s) - ‘physionet.org/files/mitdb/1.0.0/111.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:03--  https://physionet.org/files/mitdb/1.0.0/111.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 285 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/111.hea’
#
# physionet.org/files 100%[===================>]     285  --.-KB/s    in 0s
#
# 2024-05-07 04:35:03 (282 MB/s) - ‘physionet.org/files/mitdb/1.0.0/111.hea’ saved [285/285]
#
# --2024-05-07 04:35:03--  https://physionet.org/files/mitdb/1.0.0/111.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/111.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:03 (78.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/111.xws’ saved [88/88]
#
# --2024-05-07 04:35:03--  https://physionet.org/files/mitdb/1.0.0/112.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5118 (5.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/112.atr’
#
# physionet.org/files 100%[===================>]   5.00K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:04 (2.55 GB/s) - ‘physionet.org/files/mitdb/1.0.0/112.atr’ saved [5118/5118]
#
# --2024-05-07 04:35:04--  https://physionet.org/files/mitdb/1.0.0/112.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/112.dat’
#
# physionet.org/files 100%[===================>]   1.86M   278KB/s    in 6.9s
#
# 2024-05-07 04:35:11 (278 KB/s) - ‘physionet.org/files/mitdb/1.0.0/112.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:11--  https://physionet.org/files/mitdb/1.0.0/112.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 198 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/112.hea’
#
# physionet.org/files 100%[===================>]     198  --.-KB/s    in 0s
#
# 2024-05-07 04:35:11 (209 MB/s) - ‘physionet.org/files/mitdb/1.0.0/112.hea’ saved [198/198]
#
# --2024-05-07 04:35:11--  https://physionet.org/files/mitdb/1.0.0/112.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/112.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:11 (83.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/112.xws’ saved [88/88]
#
# --2024-05-07 04:35:11--  https://physionet.org/files/mitdb/1.0.0/113.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3600 (3.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/113.atr’
#
# physionet.org/files 100%[===================>]   3.52K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:12 (1.16 GB/s) - ‘physionet.org/files/mitdb/1.0.0/113.atr’ saved [3600/3600]
#
# --2024-05-07 04:35:12--  https://physionet.org/files/mitdb/1.0.0/113.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/113.dat’
#
# physionet.org/files 100%[===================>]   1.86M   266KB/s    in 6.9s
#
# 2024-05-07 04:35:19 (277 KB/s) - ‘physionet.org/files/mitdb/1.0.0/113.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:19--  https://physionet.org/files/mitdb/1.0.0/113.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 235 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/113.hea’
#
# physionet.org/files 100%[===================>]     235  --.-KB/s    in 0s
#
# 2024-05-07 04:35:19 (122 MB/s) - ‘physionet.org/files/mitdb/1.0.0/113.hea’ saved [235/235]
#
# --2024-05-07 04:35:19--  https://physionet.org/files/mitdb/1.0.0/113.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/113.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:19 (24.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/113.xws’ saved [88/88]
#
# --2024-05-07 04:35:19--  https://physionet.org/files/mitdb/1.0.0/114.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3878 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/114.atr’
#
# physionet.org/files 100%[===================>]   3.79K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:19 (693 MB/s) - ‘physionet.org/files/mitdb/1.0.0/114.atr’ saved [3878/3878]
#
# --2024-05-07 04:35:19--  https://physionet.org/files/mitdb/1.0.0/114.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/114.dat’
#
# physionet.org/files 100%[===================>]   1.86M   282KB/s    in 6.9s
#
# 2024-05-07 04:35:26 (277 KB/s) - ‘physionet.org/files/mitdb/1.0.0/114.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:26--  https://physionet.org/files/mitdb/1.0.0/114.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 160 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/114.hea’
#
# physionet.org/files 100%[===================>]     160  --.-KB/s    in 0s
#
# 2024-05-07 04:35:27 (49.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/114.hea’ saved [160/160]
#
# --2024-05-07 04:35:27--  https://physionet.org/files/mitdb/1.0.0/114.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/114.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:27 (83.9 MB/s) - ‘physionet.org/files/mitdb/1.0.0/114.xws’ saved [88/88]
#
# --2024-05-07 04:35:27--  https://physionet.org/files/mitdb/1.0.0/115.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3946 (3.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/115.atr’
#
# physionet.org/files 100%[===================>]   3.85K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:27 (1.82 GB/s) - ‘physionet.org/files/mitdb/1.0.0/115.atr’ saved [3946/3946]
#
# --2024-05-07 04:35:27--  https://physionet.org/files/mitdb/1.0.0/115.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/115.dat’
#
# physionet.org/files 100%[===================>]   1.86M   287KB/s    in 6.7s
#
# 2024-05-07 04:35:34 (284 KB/s) - ‘physionet.org/files/mitdb/1.0.0/115.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:34--  https://physionet.org/files/mitdb/1.0.0/115.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/115.hea’
#
# physionet.org/files 100%[===================>]     126  --.-KB/s    in 0s
#
# 2024-05-07 04:35:34 (63.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/115.hea’ saved [126/126]
#
# --2024-05-07 04:35:34--  https://physionet.org/files/mitdb/1.0.0/115.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/115.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:34 (43.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/115.xws’ saved [88/88]
#
# --2024-05-07 04:35:34--  https://physionet.org/files/mitdb/1.0.0/116.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4858 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/116.atr’
#
# physionet.org/files 100%[===================>]   4.74K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:35 (1.56 GB/s) - ‘physionet.org/files/mitdb/1.0.0/116.atr’ saved [4858/4858]
#
# --2024-05-07 04:35:35--  https://physionet.org/files/mitdb/1.0.0/116.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/116.dat’
#
# physionet.org/files 100%[===================>]   1.86M   267KB/s    in 7.0s
#
# 2024-05-07 04:35:42 (271 KB/s) - ‘physionet.org/files/mitdb/1.0.0/116.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:42--  https://physionet.org/files/mitdb/1.0.0/116.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/116.hea’
#
# physionet.org/files 100%[===================>]     158  --.-KB/s    in 0s
#
# 2024-05-07 04:35:42 (138 MB/s) - ‘physionet.org/files/mitdb/1.0.0/116.hea’ saved [158/158]
#
# --2024-05-07 04:35:42--  https://physionet.org/files/mitdb/1.0.0/116.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/116.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:42 (11.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/116.xws’ saved [88/88]
#
# --2024-05-07 04:35:42--  https://physionet.org/files/mitdb/1.0.0/117.at_
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3090 (3.0K) [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/117.at_’
#
# physionet.org/files 100%[===================>]   3.02K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:43 (1.95 GB/s) - ‘physionet.org/files/mitdb/1.0.0/117.at_’ saved [3090/3090]
#
# --2024-05-07 04:35:43--  https://physionet.org/files/mitdb/1.0.0/117.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3090 (3.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/117.atr’
#
# physionet.org/files 100%[===================>]   3.02K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:43 (1.81 GB/s) - ‘physionet.org/files/mitdb/1.0.0/117.atr’ saved [3090/3090]
#
# --2024-05-07 04:35:43--  https://physionet.org/files/mitdb/1.0.0/117.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/117.dat’
#
# physionet.org/files 100%[===================>]   1.86M   277KB/s    in 6.8s
#
# 2024-05-07 04:35:50 (278 KB/s) - ‘physionet.org/files/mitdb/1.0.0/117.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:50--  https://physionet.org/files/mitdb/1.0.0/117.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 127 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/117.hea’
#
# physionet.org/files 100%[===================>]     127  --.-KB/s    in 0s
#
# 2024-05-07 04:35:50 (54.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/117.hea’ saved [127/127]
#
# --2024-05-07 04:35:50--  https://physionet.org/files/mitdb/1.0.0/117.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/117.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:50 (33.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/117.xws’ saved [88/88]
#
# --2024-05-07 04:35:50--  https://physionet.org/files/mitdb/1.0.0/118.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/118.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:50 (1.42 GB/s) - ‘physionet.org/files/mitdb/1.0.0/118.atr’ saved [4622/4622]
#
# --2024-05-07 04:35:50--  https://physionet.org/files/mitdb/1.0.0/118.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/118.dat’
#
# physionet.org/files 100%[===================>]   1.86M   290KB/s    in 6.5s
#
# 2024-05-07 04:35:57 (292 KB/s) - ‘physionet.org/files/mitdb/1.0.0/118.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:35:57--  https://physionet.org/files/mitdb/1.0.0/118.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 167 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/118.hea’
#
# physionet.org/files 100%[===================>]     167  --.-KB/s    in 0s
#
# 2024-05-07 04:35:57 (135 MB/s) - ‘physionet.org/files/mitdb/1.0.0/118.hea’ saved [167/167]
#
# --2024-05-07 04:35:57--  https://physionet.org/files/mitdb/1.0.0/118.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/118.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:35:57 (76.6 MB/s) - ‘physionet.org/files/mitdb/1.0.0/118.xws’ saved [88/88]
#
# --2024-05-07 04:35:57--  https://physionet.org/files/mitdb/1.0.0/119.at_
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/119.at_’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:57 (2.23 GB/s) - ‘physionet.org/files/mitdb/1.0.0/119.at_’ saved [4812/4812]
#
# --2024-05-07 04:35:57--  https://physionet.org/files/mitdb/1.0.0/119.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/119.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2024-05-07 04:35:57 (1.23 GB/s) - ‘physionet.org/files/mitdb/1.0.0/119.atr’ saved [4812/4812]
#
# --2024-05-07 04:35:57--  https://physionet.org/files/mitdb/1.0.0/119.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/119.dat’
#
# physionet.org/files 100%[===================>]   1.86M   280KB/s    in 6.7s
#
# 2024-05-07 04:36:04 (286 KB/s) - ‘physionet.org/files/mitdb/1.0.0/119.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:36:04--  https://physionet.org/files/mitdb/1.0.0/119.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/119.hea’
#
# physionet.org/files 100%[===================>]     158  --.-KB/s    in 0s
#
# 2024-05-07 04:36:04 (65.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/119.hea’ saved [158/158]
#
# --2024-05-07 04:36:04--  https://physionet.org/files/mitdb/1.0.0/119.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/119.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:36:04 (49.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/119.xws’ saved [88/88]
#
# --2024-05-07 04:36:04--  https://physionet.org/files/mitdb/1.0.0/121.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3774 (3.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/121.atr’
#
# physionet.org/files 100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2024-05-07 04:36:05 (1.06 GB/s) - ‘physionet.org/files/mitdb/1.0.0/121.atr’ saved [3774/3774]
#
# --2024-05-07 04:36:05--  https://physionet.org/files/mitdb/1.0.0/121.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/121.dat’
#
# physionet.org/files 100%[===================>]   1.86M   283KB/s    in 6.9s
#
# 2024-05-07 04:36:12 (277 KB/s) - ‘physionet.org/files/mitdb/1.0.0/121.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:36:12--  https://physionet.org/files/mitdb/1.0.0/121.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 150 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/121.hea’
#
# physionet.org/files 100%[===================>]     150  --.-KB/s    in 0s
#
# 2024-05-07 04:36:12 (74.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/121.hea’ saved [150/150]
#
# --2024-05-07 04:36:12--  https://physionet.org/files/mitdb/1.0.0/121.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/121.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:36:12 (49.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/121.xws’ saved [88/88]
#
# --2024-05-07 04:36:12--  https://physionet.org/files/mitdb/1.0.0/122.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4970 (4.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/122.atr’
#
# physionet.org/files 100%[===================>]   4.85K  --.-KB/s    in 0s
#
# 2024-05-07 04:36:13 (1.50 GB/s) - ‘physionet.org/files/mitdb/1.0.0/122.atr’ saved [4970/4970]
#
# --2024-05-07 04:36:13--  https://physionet.org/files/mitdb/1.0.0/122.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/122.dat’
#
# physionet.org/files 100%[===================>]   1.86M   290KB/s    in 6.6s
#
# 2024-05-07 04:36:20 (287 KB/s) - ‘physionet.org/files/mitdb/1.0.0/122.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:36:20--  https://physionet.org/files/mitdb/1.0.0/122.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 221 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/122.hea’
#
# physionet.org/files 100%[===================>]     221  --.-KB/s    in 0s
#
# 2024-05-07 04:36:20 (61.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/122.hea’ saved [221/221]
#
# --2024-05-07 04:36:20--  https://physionet.org/files/mitdb/1.0.0/122.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/122.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:36:20 (50.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/122.xws’ saved [88/88]
#
# --2024-05-07 04:36:20--  https://physionet.org/files/mitdb/1.0.0/123.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3046 (3.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/123.atr’
#
# physionet.org/files 100%[===================>]   2.97K  --.-KB/s    in 0s
#
# 2024-05-07 04:36:20 (48.7 MB/s) - ‘physionet.org/files/mitdb/1.0.0/123.atr’ saved [3046/3046]
#
# --2024-05-07 04:36:20--  https://physionet.org/files/mitdb/1.0.0/123.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/123.dat’
#
# physionet.org/files 100%[===================>]   1.86M   293KB/s    in 6.5s
#
# 2024-05-07 04:36:27 (291 KB/s) - ‘physionet.org/files/mitdb/1.0.0/123.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:36:27--  https://physionet.org/files/mitdb/1.0.0/123.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 183 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/123.hea’
#
# physionet.org/files 100%[===================>]     183  --.-KB/s    in 0s
#
# 2024-05-07 04:36:27 (80.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/123.hea’ saved [183/183]
#
# --2024-05-07 04:36:27--  https://physionet.org/files/mitdb/1.0.0/123.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/123.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:36:27 (54.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/123.xws’ saved [88/88]
#
# --2024-05-07 04:36:27--  https://physionet.org/files/mitdb/1.0.0/124.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3360 (3.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/124.atr’
#
# physionet.org/files 100%[===================>]   3.28K  --.-KB/s    in 0s
#
# 2024-05-07 04:36:28 (1.28 GB/s) - ‘physionet.org/files/mitdb/1.0.0/124.atr’ saved [3360/3360]
#
# --2024-05-07 04:36:28--  https://physionet.org/files/mitdb/1.0.0/124.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/124.dat’
#
# physionet.org/files 100%[===================>]   1.86M   297KB/s    in 6.5s
#
# 2024-05-07 04:36:34 (294 KB/s) - ‘physionet.org/files/mitdb/1.0.0/124.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:36:34--  https://physionet.org/files/mitdb/1.0.0/124.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 219 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/124.hea’
#
# physionet.org/files 100%[===================>]     219  --.-KB/s    in 0s
#
# 2024-05-07 04:36:34 (113 MB/s) - ‘physionet.org/files/mitdb/1.0.0/124.hea’ saved [219/219]
#
# --2024-05-07 04:36:34--  https://physionet.org/files/mitdb/1.0.0/124.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/124.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:36:34 (55.2 MB/s) - ‘physionet.org/files/mitdb/1.0.0/124.xws’ saved [88/88]
#
# --2024-05-07 04:36:34--  https://physionet.org/files/mitdb/1.0.0/200.atr
# Connecting to physionet.org (physionet.org)|18.13.52.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8114 (7.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/200.atr’
#
# physionet.org/files 100%[===================>]   7.92K  --.-KB/s    in 0s
#
# 2024-05-07 04:36:35 (2.83 GB/s) - ‘physionet.org/files/mitdb/1.0.0/200.atr’ saved [8114/8114]
#
# --2024-05-07 04:36:35--  https://physionet.org/files/mitdb/1.0.0/200.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/200.dat’
#
# physionet.org/files 100%[===================>]   1.86M   300KB/s    in 6.4s
#
# 2024-05-07 04:36:42 (296 KB/s) - ‘physionet.org/files/mitdb/1.0.0/200.dat’ saved [1950000/1950000]
#
# --2024-05-07 04:36:42--  https://physionet.org/files/mitdb/1.0.0/200.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 306 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/200.hea’
#
# physionet.org/files 100%[===================>]     306  --.-KB/s    in 0s
#
# 2024-05-07 04:36:42 (178 MB/s) - ‘physionet.org/files/mitdb/1.0.0/200.hea’ saved [306/306]
#
# --2024-05-07 04:36:42--  https://physionet.org/files/mitdb/1.0.0/200.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/200.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-05-07 04:36:42 (51.8 MB/s) - ‘physionet.org/files/mitdb/1.0.0/200.xws’ saved [88/88]
#
# --2024-05-07 04:36:42--  https://physionet.org/files/mitdb/1.0.0/201.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4322 (4.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/201.atr’
#
# physionet.org/files 100%[===================>]   4.22K  --.-KB/s    in 0s
#
# 2024-05-07 04:36:43 (1.98 GB/s) - ‘physionet.org/files/mitdb/1.0.0/201.atr’ saved [4322/4322]
#
# --2024-05-07 04:36:43--  https://physionet.org/files/mitdb/1.0.0/201.dat
# Reusing existing connection to physionet.org:443.
# ...
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 246 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.hea’
#
# physionet.org/files 100%[===================>]     246  --.-KB/s    in 0s
#
# 2024-05-07 04:40:19 (160 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_123.hea’ saved [246/246]
#
# --2024-05-07 04:40:19--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1102 (1.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.atr’
#
# physionet.org/files 100%[===================>]   1.08K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:19 (586 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.atr’ saved [1102/1102]
#
# --2024-05-07 04:40:19--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.dat’
#
# physionet.org/files 100%[===================>] 632.81K   292KB/s    in 2.2s
#
# 2024-05-07 04:40:22 (292 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:22--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.hea’
#
# physionet.org/files 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-05-07 04:40:22 (132 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_124.hea’ saved [287/287]
#
# --2024-05-07 04:40:22--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1504 (1.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.atr’
#
# physionet.org/files 100%[===================>]   1.47K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:22 (522 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.atr’ saved [1504/1504]
#
# --2024-05-07 04:40:22--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.dat’
#
# physionet.org/files 100%[===================>] 632.81K   313KB/s    in 2.0s
#
# 2024-05-07 04:40:25 (313 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:25--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 197 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.hea’
#
# physionet.org/files 100%[===================>]     197  --.-KB/s    in 0s
#
# 2024-05-07 04:40:25 (131 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_220.hea’ saved [197/197]
#
# --2024-05-07 04:40:25--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2052 (2.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.atr’
#
# physionet.org/files 100%[===================>]   2.00K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:25 (696 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.atr’ saved [2052/2052]
#
# --2024-05-07 04:40:25--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.dat’
#
# physionet.org/files 100%[===================>] 632.81K   293KB/s    in 2.2s
#
# 2024-05-07 04:40:28 (293 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:28--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 294 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.hea’
#
# physionet.org/files 100%[===================>]     294  --.-KB/s    in 0s
#
# 2024-05-07 04:40:28 (302 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_221.hea’ saved [294/294]
#
# --2024-05-07 04:40:28--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1552 (1.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.atr’
#
# physionet.org/files 100%[===================>]   1.52K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:28 (1.13 GB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.atr’ saved [1552/1552]
#
# --2024-05-07 04:40:28--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.dat’
#
# physionet.org/files 100%[===================>] 632.81K   304KB/s    in 2.1s
#
# 2024-05-07 04:40:30 (304 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:30--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 397 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.hea’
#
# physionet.org/files 100%[===================>]     397  --.-KB/s    in 0s
#
# 2024-05-07 04:40:30 (166 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_222.hea’ saved [397/397]
#
# --2024-05-07 04:40:30--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1724 (1.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.atr’
#
# physionet.org/files 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:31 (922 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.atr’ saved [1724/1724]
#
# --2024-05-07 04:40:31--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.dat’
#
# physionet.org/files 100%[===================>] 632.81K   285KB/s    in 2.2s
#
# 2024-05-07 04:40:33 (285 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:33--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 323 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.hea’
#
# physionet.org/files 100%[===================>]     323  --.-KB/s    in 0s
#
# 2024-05-07 04:40:33 (97.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_223.hea’ saved [323/323]
#
# --2024-05-07 04:40:33--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1872 (1.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.atr’
#
# physionet.org/files 100%[===================>]   1.83K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:33 (506 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.atr’ saved [1872/1872]
#
# --2024-05-07 04:40:33--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.dat’
#
# physionet.org/files 100%[===================>] 632.81K   282KB/s    in 2.2s
#
# 2024-05-07 04:40:36 (282 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:36--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 367 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.hea’
#
# physionet.org/files 100%[===================>]     367  --.-KB/s    in 0s
#
# 2024-05-07 04:40:36 (88.3 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_228.hea’ saved [367/367]
#
# --2024-05-07 04:40:36--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2288 (2.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.atr’
#
# physionet.org/files 100%[===================>]   2.23K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:36 (497 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.atr’ saved [2288/2288]
#
# --2024-05-07 04:40:36--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.dat’
#
# physionet.org/files 100%[===================>] 632.81K   305KB/s    in 2.1s
#
# 2024-05-07 04:40:39 (305 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:39--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 198 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.hea’
#
# physionet.org/files 100%[===================>]     198  --.-KB/s    in 0s
#
# 2024-05-07 04:40:39 (102 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_230.hea’ saved [198/198]
#
# --2024-05-07 04:40:39--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2760 (2.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.atr’
#
# physionet.org/files 100%[===================>]   2.70K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:39 (670 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.atr’ saved [2760/2760]
#
# --2024-05-07 04:40:39--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.dat’
#
# physionet.org/files 100%[===================>] 632.81K   306KB/s    in 2.1s
#
# 2024-05-07 04:40:41 (306 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:41--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 397 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.hea’
#
# physionet.org/files 100%[===================>]     397  --.-KB/s    in 0s
#
# 2024-05-07 04:40:41 (50.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_231.hea’ saved [397/397]
#
# --2024-05-07 04:40:41--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1294 (1.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.atr’
#
# physionet.org/files 100%[===================>]   1.26K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:41 (152 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.atr’ saved [1294/1294]
#
# --2024-05-07 04:40:41--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.dat’
#
# physionet.org/files 100%[===================>] 632.81K   317KB/s    in 2.0s
#
# 2024-05-07 04:40:43 (317 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:43--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 453 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.hea’
#
# physionet.org/files 100%[===================>]     453  --.-KB/s    in 0s
#
# 2024-05-07 04:40:43 (179 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_232.hea’ saved [453/453]
#
# --2024-05-07 04:40:43--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2272 (2.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.atr’
#
# physionet.org/files 100%[===================>]   2.22K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:44 (1.01 GB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.atr’ saved [2272/2272]
#
# --2024-05-07 04:40:44--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.dat’
#
# physionet.org/files 100%[===================>] 632.81K   318KB/s    in 2.0s
#
# 2024-05-07 04:40:46 (318 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:46--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 229 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.hea’
#
# physionet.org/files 100%[===================>]     229  --.-KB/s    in 0s
#
# 2024-05-07 04:40:46 (86.5 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_233.hea’ saved [229/229]
#
# --2024-05-07 04:40:46--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1866 (1.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.atr’
#
# physionet.org/files 100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2024-05-07 04:40:46 (384 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.atr’ saved [1866/1866]
#
# --2024-05-07 04:40:46--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 648000 (633K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.dat’
#
# physionet.org/files 100%[===================>] 632.81K   301KB/s    in 2.1s
#
# 2024-05-07 04:40:48 (301 KB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.dat’ saved [648000/648000]
#
# --2024-05-07 04:40:48--  https://physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 223 [text/plain]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.hea’
#
# physionet.org/files 100%[===================>]     223  --.-KB/s    in 0s
#
# 2024-05-07 04:40:49 (134 MB/s) - ‘physionet.org/files/mitdb/1.0.0/x_mitdb/x_234.hea’ saved [223/223]
#
# FINISHED --2024-05-07 04:40:49--
# Total wall clock time: 6m 58s
# Downloaded: 273 files, 101M in 5m 54s (292 KB/s)

# %%
# 导入库
import wfdb
import numpy as np
import matplotlib.pyplot as plt
from spt.plot_params import set_roman_plot_params
import pywt
import pandas as pd

# %%
set_roman_plot_params()
# plt.rcParams['font.family'] = 'serif'
# plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

record = wfdb.rdrecord('./physionet.org/files/mitdb/1.0.0/109', # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=4000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channels=[0]) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']
# 小波去噪
def denoise(data):
    # 小波变换
    coeffs = pywt.wavedec(data=data, wavelet='db5', level=8)
    cD9, cD8, cD7, cD6, cD5, cD4, cD3, cD2, cD1 = coeffs

    # 阈值去噪
    threshold = (np.median(np.abs(cD1)) / 0.6745) * (np.sqrt(2 * np.log(len(cD1))))
    cD1.fill(0)
    cD2.fill(0)
    for i in range(1, len(coeffs) - 2):
        coeffs[i] = pywt.threshold(coeffs[i], threshold)

    # 小波反变换,获取去噪后的信号
    rdata = pywt.waverec(coeffs=coeffs, wavelet='db5')
    return rdata
# 转为数字信号
signal = record.d_signal[0:1000]
amplitude = (signal - np.min(signal))
amplitude = amplitude - np.mean(amplitude)
amplitude = amplitude / np.max(amplitude)
amplitude = pd.DataFrame(amplitude)
amplitude.to_csv('V_ecg.csv')  #未去噪的V类ECG数据
# plt.plot(amplitude)
# plt.show()

signal = denoise(signal)

# %%
# 获取心拍，并分类
record = wfdb.rdrecord('./physionet.org/files/mitdb/1.0.0/100', # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=4000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channels=[0]) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']
signal = record.d_signal[0:1000]
amplitude = (signal - np.min(signal))
amplitude = amplitude - np.mean(amplitude)
amplitude = amplitude / np.max(amplitude)
amplitude = pd.DataFrame(amplitude)
amplitude.to_csv('N_ecg.csv')  #未去噪的V类ECG数据


signal_ann = wfdb.rdann("./physionet.org/files/mitdb/1.0.0/100", "atr", sampfrom=0, sampto=1000)
# 将读取到的annatations的心拍绘制到心电图上

print(signal_ann.symbol)
# Out:
# ['+', 'N', 'N', 'N', 'N']

# %%
# 找出F类心拍
url= './physionet.org/files/mitdb/1.0.0/208'
record = wfdb.rdrecord(url, # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=4000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channels=[0]) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']
signal = record.d_signal[0:4000]
amplitude = (signal - np.min(signal))
amplitude = amplitude - np.mean(amplitude)
amplitude = amplitude / np.max(amplitude)
amplitude = pd.DataFrame(amplitude)
amplitude.to_csv('F_ecg.csv')  #未去噪的V类ECG数据


signal_ann = wfdb.rdann(url, "atr", sampfrom=0, sampto=1000)
# 将读取到的annatations的心拍绘制到心电图上

print(signal_ann.symbol)
# Out:
# ['+', 'F', 'V', 'N', 'F', 'V']

# %%
# 找出S类心拍
url= './physionet.org/files/mitdb/1.0.0/202'
record = wfdb.rdrecord(url, # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=38000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channels=[0]) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']
signal = record.d_signal[0:8000]
amplitude = (signal - np.min(signal))
amplitude = amplitude - np.mean(amplitude)
amplitude = amplitude / np.max(amplitude)
amplitude = pd.DataFrame(amplitude)
# amplitude.to_csv('S_ecg.csv')  #未去噪的V类ECG数据


signal_ann = wfdb.rdann(url, "atr", sampfrom=0)
# 将读取到的annatations的心拍绘制到心电图上
s_beats = np.where(signal_ann.symbol == 'S')[0]
print(s_beats)
# Out:
# []
# <ipython-input-93-78dbb949b590>:18: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   s_beats = np.where(signal_ann.symbol == 'S')[0]

# %%
import os
import wfdb

# Change directory to the desired folder
os.chdir('./physionet.org/files/mitdb/1.0.0/')

# Initialize an empty list to store the S-type heartbeats
s_type_beats = []

# Loop through all files in the directory
for filename in os.listdir():
    # Check if the file ends with '.atr'
    if filename.endswith('.atr'):
        # Extract the filename without extension
        base_filename = os.path.splitext(filename)[0]

        # Read the annotation file
        annotation = wfdb.rdann(base_filename, 'atr')

        # Loop through each annotation
        for annotation_sample, annotation_symbol in zip(annotation.sample, annotation.symbol):
            # Check if the symbol is 'S'
            if annotation_symbol == 'S':
                # Add the sample number to the list
                s_type_beats.append(annotation_sample)

# Print the list of S-type heartbeats
print(s_type_beats)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cfb4b011521a> in <cell line: 2>()
#       1 import os
# ----> 2 import wfdb
#       3
#       4 # Change directory to the desired folder
#       5 os.chdir('./physionet.org/files/mitdb/1.0.0/')
#
# ModuleNotFoundError: No module named 'wfdb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
